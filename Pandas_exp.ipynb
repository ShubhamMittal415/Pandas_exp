# %%
import pandas as pd
import numpy as np

# %%
data=pd.read_csv("C:/Users/shubham.mittal/Downloads/business-employment-data-march-2023-quarter/machine-readable-business-employment-data-mar-2023-quarter.csv")

# %%
data.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06     80078.0        NaN      F  Number          0
# 1      BDCQ.SEA1AA  2011.09     78324.0        NaN      F  Number          0
# 2      BDCQ.SEA1AA  2011.12     85850.0        NaN      F  Number          0
# 3      BDCQ.SEA1AA  2012.03     90743.0        NaN      F  Number          0
# 4      BDCQ.SEA1AA  2012.06     81780.0        NaN      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3  \
# ...

# %%
data.tail()
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS   UNITS  \
# 21410    BDCQ.SEE3999A  2017.06         NaN          Y      C  Number
# 21411    BDCQ.SEE3999A  2017.09         NaN          Y      C  Number
# 21412    BDCQ.SEE3999A  2017.12         NaN          Y      C  Number
# 21413    BDCQ.SEE3999A  2018.03         NaN          Y      C  Number
# 21414    BDCQ.SEE3999A  2018.06         NaN          Y      C  Number
#
#        Magnitude                         Subject  \
# 21410          0  Business Data Collection - BDC
# 21411          0  Business Data Collection - BDC
# 21412          0  Business Data Collection - BDC
# 21413          0  Business Data Collection - BDC
# 21414          0  Business Data Collection - BDC
#
#                                               Group  \
# 21410  Territorial authority by employment variable
# 21411  Territorial authority by employment variable
# 21412  Territorial authority by employment variable
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 21415 entries, 0 to 21414
# Data columns (total 14 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Series_reference  21415 non-null  object
#  1   Period            21415 non-null  float64
#  2   Data_value        16848 non-null  float64
#  3   Suppressed        4567 non-null   object
#  4   STATUS            21415 non-null  object
#  5   UNITS             21415 non-null  object
#  6   Magnitude         21415 non-null  int64
#  7   Subject           21415 non-null  object
#  8   Group             21415 non-null  object
#  9   Series_title_1    21415 non-null  object
#  10  Series_title_2    21415 non-null  object
#  11  Series_title_3    21415 non-null  object
#  12  Series_title_4    0 non-null      float64
#  13  Series_title_5    0 non-null      float64
# dtypes: float64(4), int64(1), object(9)
# memory usage: 2.3+ MB

# %%
data.describe()
# Out:
#              Period    Data_value     Magnitude  Series_title_4  \
# count  21415.000000  1.684800e+04  21415.000000             0.0
# mean    2016.672724  6.227105e+04      2.347046             NaN
# std        3.417746  1.882630e+05      2.928148             NaN
# min     2011.060000  1.187001e+00      0.000000             NaN
# 25%     2014.030000  1.254750e+03      0.000000             NaN
# 50%     2017.030000  1.073100e+04      0.000000             NaN
# 75%     2019.120000  4.367800e+04      6.000000             NaN
# max     2023.030000  2.261414e+06      6.000000             NaN
#
#        Series_title_5
# count             0.0
# mean              NaN
# std               NaN
# min               NaN
# 25%               NaN
# 50%               NaN
# 75%               NaN
# max               NaN

# %%
data.shape
# Out:
# (21415, 14)

# %%
data.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           4567
# Suppressed          16848
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4      21415
# Series_title_5      21415
# dtype: int64

# %%
data=data.drop(['Suppressed','Series_title_4','Series_title_5'],axis=1)

# %%
print(data)
# Out:
#       Series_reference   Period  Data_value STATUS   UNITS  Magnitude  \
# 0          BDCQ.SEA1AA  2011.06     80078.0      F  Number          0
# 1          BDCQ.SEA1AA  2011.09     78324.0      F  Number          0
# 2          BDCQ.SEA1AA  2011.12     85850.0      F  Number          0
# 3          BDCQ.SEA1AA  2012.03     90743.0      F  Number          0
# 4          BDCQ.SEA1AA  2012.06     81780.0      F  Number          0
# ...                ...      ...         ...    ...     ...        ...
# 21410    BDCQ.SEE3999A  2017.06         NaN      C  Number          0
# 21411    BDCQ.SEE3999A  2017.09         NaN      C  Number          0
# 21412    BDCQ.SEE3999A  2017.12         NaN      C  Number          0
# 21413    BDCQ.SEE3999A  2018.03         NaN      C  Number          0
# 21414    BDCQ.SEE3999A  2018.06         NaN      C  Number          0
#
#                               Subject  \
# 0      Business Data Collection - BDC
# 1      Business Data Collection - BDC
# ...

# %%
data=data.drop(['Data_value'],axis=1)

# %%
data.head()
# Out:
#   Series_reference   Period STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06      F  Number          0
# 1      BDCQ.SEA1AA  2011.09      F  Number          0
# 2      BDCQ.SEA1AA  2011.12      F  Number          0
# 3      BDCQ.SEA1AA  2012.03      F  Number          0
# 4      BDCQ.SEA1AA  2012.06      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
# ...

# %%
data.duplicated()
# Out:
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 21410    False
# 21411    False
# 21412    False
# 21413    False
# 21414    False
# Length: 21415, dtype: bool

# %%
data.duplicated(keep=False).sum()
# Out:
# 0

# %%
data.head()
# Out:
#   Series_reference   Period STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06      F  Number          0
# 1      BDCQ.SEA1AA  2011.09      F  Number          0
# 2      BDCQ.SEA1AA  2011.12      F  Number          0
# 3      BDCQ.SEA1AA  2012.03      F  Number          0
# 4      BDCQ.SEA1AA  2012.06      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
# ...

# %%
data.tail(10)
# Out:
#       Series_reference   Period STATUS   UNITS  Magnitude  \
# 21405    BDCQ.SEE3999A  2016.03      C  Number          0
# 21406    BDCQ.SEE3999A  2016.06      C  Number          0
# 21407    BDCQ.SEE3999A  2016.09      C  Number          0
# 21408    BDCQ.SEE3999A  2016.12      C  Number          0
# 21409    BDCQ.SEE3999A  2017.03      C  Number          0
# 21410    BDCQ.SEE3999A  2017.06      C  Number          0
# 21411    BDCQ.SEE3999A  2017.09      C  Number          0
# 21412    BDCQ.SEE3999A  2017.12      C  Number          0
# 21413    BDCQ.SEE3999A  2018.03      C  Number          0
# 21414    BDCQ.SEE3999A  2018.06      C  Number          0
#
#                               Subject  \
# 21405  Business Data Collection - BDC
# 21406  Business Data Collection - BDC
# 21407  Business Data Collection - BDC
# 21408  Business Data Collection - BDC
# 21409  Business Data Collection - BDC
# 21410  Business Data Collection - BDC
# 21411  Business Data Collection - BDC
# ...

# %%
data.drop_duplicates()
# Out:
#       Series_reference   Period STATUS   UNITS  Magnitude  \
# 0          BDCQ.SEA1AA  2011.06      F  Number          0
# 1          BDCQ.SEA1AA  2011.09      F  Number          0
# 2          BDCQ.SEA1AA  2011.12      F  Number          0
# 3          BDCQ.SEA1AA  2012.03      F  Number          0
# 4          BDCQ.SEA1AA  2012.06      F  Number          0
# ...                ...      ...    ...     ...        ...
# 21410    BDCQ.SEE3999A  2017.06      C  Number          0
# 21411    BDCQ.SEE3999A  2017.09      C  Number          0
# 21412    BDCQ.SEE3999A  2017.12      C  Number          0
# 21413    BDCQ.SEE3999A  2018.03      C  Number          0
# 21414    BDCQ.SEE3999A  2018.06      C  Number          0
#
#                               Subject  \
# 0      Business Data Collection - BDC
# 1      Business Data Collection - BDC
# 2      Business Data Collection - BDC
# 3      Business Data Collection - BDC
# 4      Business Data Collection - BDC
# ...

# %%
data.shape
# Out:
# (21415, 10)

# %%
data.Series_title_3.unique()
# Out:
# array(['Actual', 'Seasonally adjusted', 'Trend'], dtype=object)

# %%
data.Series_title_3.unique()
# Out:
# array(['Actual', 'Seasonally adjusted', 'Trend'], dtype=object)

# %%
data.Series_title_3.nunique()
# Out:
# 3

# %%
data.dropna()
# Out:
#       Series_reference   Period STATUS   UNITS  Magnitude  \
# 0          BDCQ.SEA1AA  2011.06      F  Number          0
# 1          BDCQ.SEA1AA  2011.09      F  Number          0
# 2          BDCQ.SEA1AA  2011.12      F  Number          0
# 3          BDCQ.SEA1AA  2012.03      F  Number          0
# 4          BDCQ.SEA1AA  2012.06      F  Number          0
# ...                ...      ...    ...     ...        ...
# 21410    BDCQ.SEE3999A  2017.06      C  Number          0
# 21411    BDCQ.SEE3999A  2017.09      C  Number          0
# 21412    BDCQ.SEE3999A  2017.12      C  Number          0
# 21413    BDCQ.SEE3999A  2018.03      C  Number          0
# 21414    BDCQ.SEE3999A  2018.06      C  Number          0
#
#                               Subject  \
# 0      Business Data Collection - BDC
# 1      Business Data Collection - BDC
# 2      Business Data Collection - BDC
# 3      Business Data Collection - BDC
# 4      Business Data Collection - BDC
# ...

# %%
data.head()
# Out:
#   Series_reference   Period STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06      F  Number          0
# 1      BDCQ.SEA1AA  2011.09      F  Number          0
# 2      BDCQ.SEA1AA  2011.12      F  Number          0
# 3      BDCQ.SEA1AA  2012.03      F  Number          0
# 4      BDCQ.SEA1AA  2012.06      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
# ...

# %%
data.shape
# Out:
# (21415, 10)

# %%
data.Magnitude.nunique()
# Out:
# 2

# %%
data.UNITS.nunique()
# Out:
# 2

# %%
data.UNITS.unique()
# Out:
# array(['Number', 'Value'], dtype=object)

# %%
data.STATUS.nunique()
# Out:
# 3

# %%
data.STATUS.unique()
# Out:
# array(['F', 'R', 'C'], dtype=object)

# %%
data.groupby('STATUS').size()
# Out:
# STATUS
# C     3239
# F    12110
# R     6066
# dtype: int64

# %%
data.groupby('Magnitude').size()
# Out:
# Magnitude
# 0    13038
# 6     8377
# dtype: int64

# %%
data.groupby('UNITS').size()
# Out:
# UNITS
# Number    13038
# Value      8377
# dtype: int64

# %%
data.head()
# Out:
#   Series_reference   Period STATUS   UNITS  Magnitude  \
# 0      BDCQ.SEA1AA  2011.06      F  Number          0
# 1      BDCQ.SEA1AA  2011.09      F  Number          0
# 2      BDCQ.SEA1AA  2011.12      F  Number          0
# 3      BDCQ.SEA1AA  2012.03      F  Number          0
# 4      BDCQ.SEA1AA  2012.06      F  Number          0
#
#                           Subject                            Group  \
# 0  Business Data Collection - BDC  Industry by employment variable
# 1  Business Data Collection - BDC  Industry by employment variable
# 2  Business Data Collection - BDC  Industry by employment variable
# 3  Business Data Collection - BDC  Industry by employment variable
# 4  Business Data Collection - BDC  Industry by employment variable
#
#   Series_title_1                     Series_title_2 Series_title_3
# 0    Filled jobs  Agriculture, Forestry and Fishing         Actual
# 1    Filled jobs  Agriculture, Forestry and Fishing         Actual
# ...

# %%
# %pip install matplotlib
# Out:
# ...
# WARNING: You are using pip version 21.2.3; however, version 23.1.2 is available.
# You should consider upgrading via the 'C:\Users\shubham.mittal\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
data.Magnitude.unique()
# Out:
# array([0, 6], dtype=int64)

# %%
import matplotlib.pyplot as plt

# %%
# Out:
#   Cell In[87], line 1
#     ax = plt.axes()plt.plot(data.Magnitude.unique(), data.Magnitude.value_counts())
#          ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?
